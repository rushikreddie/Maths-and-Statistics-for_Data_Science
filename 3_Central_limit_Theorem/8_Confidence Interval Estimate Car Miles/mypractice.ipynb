# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("miles.csv")

# %%
plt.figure(figsize=(12,4))
plt.plot(df.miles)

# %%
sns.histplot(df.miles,kde=True)
# Out:
# <Axes: xlabel='miles', ylabel='Count'>

# %%
mean_population=df.miles.mean()
std_population=df.miles.std()
mean_population, std_population
# Out:
# (np.float64(27.627397260273973), np.float64(15.437588497596291))

# %%
SAMPLE_SIZE=50
sample=df.sample(SAMPLE_SIZE,random_state=100)
sample.head()
# Out:
#            date  is_weekend  miles
# 184  2022-07-04       False     24
# 535  2023-06-20       False     36
# 299  2022-10-27       False     41
# 221  2022-08-10       False     20
# 152  2022-06-02       False     38

# %%
sample.shape
# Out:
# (50, 3)

# %%
mean_sample=sample.miles.mean()
std_sample=sample.miles.std()
mean_sample, std_sample
# Out:
# (np.float64(25.82), np.float64(8.805587280070466))

# %%
# !pip install scipy
# Out:
# ...
#    ---------------------------------------- 0.0/41.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/41.3 MB ? eta -:--:--
#    - -------------------------------------- 1.0/41.3 MB 4.2 MB/s eta 0:00:10
#    -- ------------------------------------- 2.1/41.3 MB 4.5 MB/s eta 0:00:09
#    --- ------------------------------------ 3.1/41.3 MB 5.3 MB/s eta 0:00:08
#    --- ------------------------------------ 3.9/41.3 MB 4.5 MB/s eta 0:00:09
#    ------ --------------------------------- 6.3/41.3 MB 5.8 MB/s eta 0:00:06
#    -------- ------------------------------- 8.7/41.3 MB 6.8 MB/s eta 0:00:05
#    ----------- ---------------------------- 11.5/41.3 MB 7.8 MB/s eta 0:00:04
#    ------------- -------------------------- 13.9/41.3 MB 8.3 MB/s eta 0:00:04
#    ---------------- ----------------------- 17.0/41.3 MB 9.0 MB/s eta 0:00:03
#    ------------------- -------------------- 20.4/41.3 MB 9.7 MB/s eta 0:00:03
# ...

# %%
import  scipy.stats as st

# %%
zscore_95_confidence=st.norm.ppf(0.975)
zscore_95_confidence
# Out:
# np.float64(1.959963984540054)

# %%
import numpy as np

# %%
margin_of_error=zscore_95_confidence * (std_population)/np.sqrt(SAMPLE_SIZE)
margin_of_error
# Out:
# np.float64(4.2790025875110596)

# %%
upper = mean_sample + margin_of_error
lower = mean_sample - margin_of_error
lower, upper
# Out:
# (np.float64(21.54099741248894), np.float64(30.09900258751106))
